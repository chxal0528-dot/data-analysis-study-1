# %%
import pandas as pd
import os

# %%
# ===================== 1. 德甲数据（10支，含数据不全的队伍） =====================
bundesliga_data = [
    {"联赛": "德甲", "俱乐部": "拜耳04勒沃库森", "支出(欧元)": "1.815亿", "收入(欧元)": "229.50万", "收支平衡(欧元)": "3135万"},
    {"联赛": "德甲", "俱乐部": "莱比锡RB", "支出(欧元)": "1360万", "收入(欧元)": "1.971亿", "收支平衡(欧元)": "6110万"},
    {"联赛": "德甲", "俱乐部": "多特蒙德", "支出(欧元)": "9970万", "收入(欧元)": "7275万", "收支平衡(欧元)": "-2695万"},
    {"联赛": "德甲", "俱乐部": "拜仁慕尼黑", "支出(欧元)": "8880万", "收入(欧元)": "9895万", "收支平衡(欧元)": "1015万"},
    {"联赛": "德甲", "俱乐部": "法兰克福", "支出(欧元)": "6510万", "收入(欧元)": "1.267亿", "收支平衡(欧元)": "6160万"},
    {"联赛": "德甲", "俱乐部": "VfB斯图加特", "支出(欧元)": "5200万", "收入(欧元)": "1.1565亿", "收支平衡(欧元)": "6365万"},
    {"联赛": "德甲", "俱乐部": "沃尔夫斯堡", "支出(欧元)": "4765万", "收入(欧元)": "3750万", "收支平衡(欧元)": "-1015万"},
    {"联赛": "德甲", "俱乐部": "SC弗赖堡", "支出(欧元)": "3270万", "收入(欧元)": "3090万", "收支平衡(欧元)": "180万"},
    {"联赛": "德甲", "俱乐部": "1.科隆足球俱乐部", "支出(欧元)": "2443万", "收入(欧元)": "", "收支平衡(欧元)": "-1203万"},  # 收入缺失
    {"联赛": "德甲", "俱乐部": "奥格斯堡足球俱乐部", "支出(欧元)": "", "收入(欧元)": "1330万", "收支平衡(欧元)": "-1090万"}  # 支出缺失
]
df_bundesliga = pd.DataFrame(bundesliga_data)
df_bundesliga.to_csv("德甲财务数据.csv", index=False, encoding="utf-8-sig")
print(f"✅ 德甲CSV生成完成：{os.path.join(os.getcwd(), '德甲财务数据.csv')}")
# Out:
# ✅ 德甲CSV生成完成：/Users/shang/德甲财务数据.csv

# %%
# ===================== 2. 日本J1联赛数据（10支，含数据不全的队伍） =====================
j1_data = [
    {"联赛": "日本J1联赛", "俱乐部": "Sanfrecce Hiroshima", "支出(欧元)": "350万", "收入(欧元)": "150万", "收支平衡(欧元)": "-200万"},
    {"联赛": "日本J1联赛", "俱乐部": "Gamba Osaka", "支出(欧元)": "285万", "收入(欧元)": "225万", "收支平衡(欧元)": "-60.3万"},
    {"联赛": "日本J1联赛", "俱乐部": "Urawa Red Diamonds", "支出(欧元)": "220万", "收入(欧元)": "205万", "收支平衡(欧元)": "-15万"},
    {"联赛": "日本J1联赛", "俱乐部": "Yokohama F. Marinos", "支出(欧元)": "175万", "收入(欧元)": "", "收支平衡(欧元)": "-175万"},  # 收入缺失
    {"联赛": "英超", "俱乐部": "西汉姆联", "支出(欧元)": "6500万", "收入(欧元)": "5000万", "收支平衡(欧元)": "-1500万"}
]
# 生成英超CSV（逐个生成第三步）
df_premier = pd.DataFrame(premier_data)
df_premier.to_csv("英超财务数据.csv", index=False, encoding="utf-8-sig")
print(f"✅ 英超CSV生成完成：{os.path.join(os.getcwd(), '英超财务数据.csv')}")
# Out:
# ✅ 英超CSV生成完成：/Users/shang/英超财务数据.csv

# %%
# ===================== 4. 中超数据（10支，含数据不全的队伍） =====================
csl_data = [
    {"联赛": "中超", "俱乐部": "上海海港", "支出(欧元)": "1200万", "收入(欧元)": "800万", "收支平衡(欧元)": "-400万"},
    {"联赛": "中超", "俱乐部": "北京国安", "支出(欧元)": "950万", "收入(欧元)": "700万", "收支平衡(欧元)": "-250万"},
    {"联赛": "中超", "俱乐部": "山东泰山", "支出(欧元)": "880万", "收入(欧元)": "", "收支平衡(欧元)": "-230万"},  # 收入缺失
    {"联赛": "中超", "俱乐部": "武汉三镇", "支出(欧元)": "750万", "收入(欧元)": "500万", "收支平衡(欧元)": "-250万"},
    {"联赛": "中超", "俱乐部": "浙江队", "支出(欧元)": "600万", "收入(欧元)": "400万", "收支平衡(欧元)": "-200万"},
    {"联赛": "中超", "俱乐部": "成都蓉城", "支出(欧元)": "550万", "收入(欧元)": "350万", "收支平衡(欧元)": ""},  # 收支平衡缺失
    {"联赛": "中超", "俱乐部": "天津津门虎", "支出(欧元)": "", "收入(欧元)": "300万", "收支平衡(欧元)": "-150万"},  # 支出缺失
    {"联赛": "中超", "俱乐部": "河南队", "支出(欧元)": "450万", "收入(欧元)": "280万", "收支平衡(欧元)": "-170万"},
    {"联赛": "中超", "俱乐部": "长春亚泰", "支出(欧元)": "400万", "收入(欧元)": "250万", "收支平衡(欧元)": "-150万"},
    {"联赛": "中超", "俱乐部": "大连英博", "支出(欧元)": "350万", "收入(欧元)": "200万", "收支平衡(欧元)": "-150万"}
]
# 生成中超CSV（逐个生成第四步）
df_csl = pd.DataFrame(csl_data)
df_csl.to_csv("中超财务数据.csv", index=False, encoding="utf-8-sig")
print(f"✅ 中超CSV生成完成：{os.path.join(os.getcwd(), '中超财务数据.csv')}")
# Out:
# ✅ 中超CSV生成完成：/Users/shang/中超财务数据.csv

# %%
# ===================== 可选：生成汇总CSV（方便后续统一处理） =====================
all_data = bundesliga_data + j1_data + premier_data + csl_data
df_total = pd.DataFrame(all_data)
df_total.to_csv("四国联赛财务收支汇总.csv", index=False, encoding="utf-8-sig")
print(f"✅ 汇总CSV生成完成：{os.path.join(os.getcwd(), '四国联赛财务收支汇总.csv')}")
# Out:
# ✅ 汇总CSV生成完成：/Users/shang/四国联赛财务收支汇总.csv
