# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
country_league_urls = {
    "中国": "https://www.transfermarkt.com/chinese-super-league/startseite/wettbewerb/CSL",
    "英国": "https://www.transfermarkt.com/premier-league/startseite/wettbewerb/GB1",
    "德国": "https://www.transfermarkt.com/bundesliga/startseite/wettbewerb/L1",
    "日本": "https://www.transfermarkt.com/j1-league/startseite/wettbewerb/J1"
}
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Referer": "https://www.transfermarkt.com/"}

# %%
all_data = []

# %%
import time
import os

# %%
current_path = os.getcwd()
print(f"⚠️ 所有数据会保存到这个文件夹：{current_path}")
# Out:
# ⚠️ 所有数据会保存到这个文件夹：/Users/shang

# %%
import pandas as pd
league_data = [
    {"联赛名称": "Chinese Super League", "国家/地区": "中国", "球队数量": 16, "球员数量": 502, "平均年龄": 27.8, "总市场价值": "€136.43m"},
    {"联赛名称": "J1 League", "国家/地区": "日本", "球队数量": 20, "球员数量": 708, "平均年龄": 26.8, "总市场价值": "€308.10m"},
    {"联赛名称": "Premier League", "国家/地区": "英格兰", "球队数量": 20, "球员数量": 542, "平均年龄": 26.3, "总市场价值": "€12.53bn"},
    {"联赛名称": "Bundesliga", "国家/地区": "德国", "球队数量": 18, "球员数量": 524, "平均年龄": 25.8, "总市场价值": "€4.81bn"}
]
df = pd.DataFrame(league_data)
df.to_csv("各国联赛数据汇总.csv", index=False, encoding="utf-8-sig")

print("✅ 数据已存入DataFrame并导出为CSV！")
print("📊 DataFrame预览：")
print(df)
# Out:
# ✅ 数据已存入DataFrame并导出为CSV！
# 📊 DataFrame预览：
#   国家/地区  平均年龄     总市场价值  球员数量  球队数量                  联赛名称
# 0    中国  27.8  €136.43m   502    16  Chinese Super League
# 1    日本  26.8  €308.10m   708    20             J1 League
# 2   英格兰  26.3  €12.53bn   542    20        Premier League
# 3    德国  25.8   €4.81bn   524    18            Bundesliga

# %%
print("列名顺序：", df.columns.tolist())
print("\n第一行数据：", df.iloc[0].tolist())
# Out:
# 列名顺序： ['国家/地区', '平均年龄', '总市场价值', '球员数量', '球队数量', '联赛名称']
#
# 第一行数据： ['中国', 27.800000000000001, '€136.43m', 502, 16, 'Chinese Super League']

# %%
print("代码运行的文件夹路径：", os.getcwd())
# 打印CSV文件的完整路径
csv_path = os.path.join(os.getcwd(), "各国联赛数据汇总.csv")
print("CSV文件的完整路径：", csv_path)
# Out:
# 代码运行的文件夹路径： /Users/shang
# CSV文件的完整路径： /Users/shang/各国联赛数据汇总.csv
